# %% [markdown]
# #lab-07

# %% [markdown]
# *Nikhil Kuchana*

# %% [markdown]
# **2303A51LB0**

# %% [markdown]
# 1.Use a simple dataset for English-to-French translation. You can either use a small dataset like this or download a more extensive dataset such as the Tab-delimited Bilingual Sentence Pairs dataset from Tatoeba or Parallel Corpus from the European Parliament.
#
# Example data (small English to French pairs)
#
# data = [ ("hello", "bonjour"), ("how are you", "comment ça va"), ("I am fine", "je vais bien"), ("what is your name", "comment tu t'appelles"), ("my name is", "je m'appelle"), ("thank you", "merci"), ("goodbye", "au revoir") ]  [CO4]
#
#
#
# (a) Data Preprocessing
#
# (b) Build Seq2Seq Model
#
# (c) Preparing the Data for Training
#
#  (d) Train the model on the dataset
#
# (e) Inference Setup for Translation
#
# (f) Translate New Sentences
#
# (g) Experimenting and Improving the Model by large dataset and hyper tune parameter.

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Sample dataset
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("I am fine", "je vais bien"),
    ("what is your name", "comment tu t'appelles"),
    ("my name is", "je m'appelle"),
    ("thank you", "merci"),
    ("goodbye", "au revoir")
]

# (a) Data Preprocessing
def preprocess_data(data):
    # Split English and French sentences
    eng_texts = [pair[0] for pair in data]
    fra_texts = ['<start> ' + pair[1] + ' <end>' for pair in data]

    # Create tokenizers
    eng_tokenizer = Tokenizer()
    fra_tokenizer = Tokenizer()

    # Fit tokenizers
    eng_tokenizer.fit_on_texts(eng_texts)
    fra_tokenizer.fit_on_texts(fra_texts)

    # Convert texts to sequences
    eng_sequences = eng_tokenizer.texts_to_sequences(eng_texts)
    fra_sequences = fra_tokenizer.texts_to_sequences(fra_texts)

    # Find maximum lengths
    max_eng_len = max(len(seq) for seq in eng_sequences)
    max_fra_len = max(len(seq) for seq in fra_sequences)

    # Pad sequences
    eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
    fra_padded = pad_sequences(fra_sequences, maxlen=max_fra_len, padding='post')

    return eng_padded, fra_padded, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len

# Process the data
eng_data, fra_data, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len = preprocess_data(data)

# Get vocabulary sizes
eng_vocab_size = len(eng_tokenizer.word_index) + 1
fra_vocab_size = len(fra_tokenizer.word_index) + 1

# Print shapes for debugging
print("Input shapes:")
print(f"English data shape: {eng_data.shape}")
print(f"French data shape: {fra_data.shape}")

# (b) Build Seq2Seq Model
def build_model(input_vocab, output_vocab, input_length, output_length):
    # Encoder
    encoder_inputs = Input(shape=(input_length,))
    encoder_embedding = Embedding(input_vocab, 50)(encoder_inputs)
    encoder = LSTM(100, return_state=True)
    encoder_outputs, state_h, state_c = encoder(encoder_embedding)
    encoder_states = [state_h, state_c]

    # Decoder
    decoder_inputs = Input(shape=(output_length,))
    decoder_embedding = Embedding(output_vocab, 50)(decoder_inputs)
    decoder_lstm = LSTM(100, return_sequences=True)
    decoder_outputs = decoder_lstm(decoder_embedding, initial_state=encoder_states)
    decoder_dense = Dense(output_vocab, activation='softmax')
    decoder_outputs = decoder_dense(decoder_outputs)

    # Create model
    model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
    return model

# (c) Prepare Data for Training
decoder_input_data = fra_data[:, :-1]  # Remove last token
decoder_target_data = fra_data[:, 1:]  # Remove first token

# Print shapes for debugging
print("\nTraining data shapes:")
print(f"Decoder input shape: {decoder_input_data.shape}")
print(f"Decoder target shape: {decoder_target_data.shape}")

# (d) Train the Model
model = build_model(
    eng_vocab_size,
    fra_vocab_size,
    max_eng_len,
    max_fra_len - 1
)

# Compile model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    [eng_data, decoder_input_data],
    decoder_target_data,
    batch_size=2,
    epochs=100,
    validation_split=0.2
)

# (e) Inference Setup
class Translator:
    def __init__(self, model, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len):
        self.model = model
        self.eng_tokenizer = eng_tokenizer
        self.fra_tokenizer = fra_tokenizer
        self.max_eng_len = max_eng_len
        self.max_fra_len = max_fra_len
        self.fra_index_word = {v: k for k, v in fra_tokenizer.word_index.items()}

    def translate(self, text):
        # Tokenize input text
        sequence = self.eng_tokenizer.texts_to_sequences([text])
        padded = pad_sequences(sequence, maxlen=self.max_eng_len, padding='post')

        # Initialize target sequence
        target_seq = np.zeros((1, self.max_fra_len - 1))

        # Generate translation
        prediction = self.model.predict([padded, target_seq])

        # Convert prediction to text
        output_sequence = np.argmax(prediction[0], axis=1)
        translated_text = []

        for idx in output_sequence:
            if idx != 0:
                word = self.fra_index_word.get(idx, '')
                if word and word not in ['<start>', '<end>']:
                    translated_text.append(word)

        return ' '.join(translated_text)

# (f) Translate New Sentences
translator = Translator(model, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len)

# Test translations
test_sentences = [
    "hello",
    "thank you",
    "your name",
    "how are you"
]

print("\nTranslations:")
for sentence in test_sentences:
    translation = translator.translate(sentence)
    print(f"English: {sentence}")
    print(f"French: {translation}\n")
# Out:
# Input shapes:
# English data shape: (7, 4)
# French data shape: (7, 5)
#
# Training data shapes:
# Decoder input shape: (7, 4)
# Decoder target shape: (7, 4)
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 408ms/step - accuracy: 0.1063 - loss: 2.7718 - val_accuracy: 0.1250 - val_loss: 2.7667
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4187 - loss: 2.7543 - val_accuracy: 0.3750 - val_loss: 2.7523
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3719 - loss: 2.7400 - val_accuracy: 0.3750 - val_loss: 2.7373
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3313 - loss: 2.7235 - val_accuracy: 0.5000 - val_loss: 2.7169
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3313 - loss: 2.6966 - val_accuracy: 0.6250 - val_loss: 2.6881
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4656 - loss: 2.6571 - val_accuracy: 0.6250 - val_loss: 2.6485
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3313 - loss: 2.6251 - val_accuracy: 0.2500 - val_loss: 2.5930
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2500 - loss: 2.5650 - val_accuracy: 0.2500 - val_loss: 2.5065
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2500 - loss: 2.4890 - val_accuracy: 0.2500 - val_loss: 2.3788
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2500 - loss: 2.3797 - val_accuracy: 0.2500 - val_loss: 2.2144
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2500 - loss: 2.1747 - val_accuracy: 0.2500 - val_loss: 2.1193
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2500 - loss: 2.2070 - val_accuracy: 0.2500 - val_loss: 2.1545
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2500 - loss: 2.0895 - val_accuracy: 0.5000 - val_loss: 2.1252
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3719 - loss: 2.1201 - val_accuracy: 0.5000 - val_loss: 2.1041
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3625 - loss: 1.9812 - val_accuracy: 0.5000 - val_loss: 2.1066
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3625 - loss: 1.9123 - val_accuracy: 0.5000 - val_loss: 2.1281
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4031 - loss: 1.7658 - val_accuracy: 0.5000 - val_loss: 2.1601
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5719 - loss: 1.7850 - val_accuracy: 0.5000 - val_loss: 2.2079
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5406 - loss: 1.7879 - val_accuracy: 0.6250 - val_loss: 2.2819
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5656 - loss: 1.8640 - val_accuracy: 0.5000 - val_loss: 2.3816
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6125 - loss: 1.6195 - val_accuracy: 0.5000 - val_loss: 2.5008
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5656 - loss: 1.7565 - val_accuracy: 0.5000 - val_loss: 2.6120
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6125 - loss: 1.4973 - val_accuracy: 0.5000 - val_loss: 2.7232
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5969 - loss: 1.5426 - val_accuracy: 0.5000 - val_loss: 2.8419
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4938 - loss: 1.5775 - val_accuracy: 0.5000 - val_loss: 2.9935
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5719 - loss: 1.3140 - val_accuracy: 0.5000 - val_loss: 3.1698
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6844 - loss: 1.2156 - val_accuracy: 0.5000 - val_loss: 3.3128
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7156 - loss: 1.0407 - val_accuracy: 0.3750 - val_loss: 3.4355
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6531 - loss: 1.1285 - val_accuracy: 0.3750 - val_loss: 3.5791
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6687 - loss: 1.0613 - val_accuracy: 0.5000 - val_loss: 3.7431
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6938 - loss: 0.9899 - val_accuracy: 0.5000 - val_loss: 3.9037
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7656 - loss: 0.8931 - val_accuracy: 0.5000 - val_loss: 3.9995
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7031 - loss: 0.9453 - val_accuracy: 0.5000 - val_loss: 4.1216
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8281 - loss: 0.6319 - val_accuracy: 0.5000 - val_loss: 4.2511
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7500 - loss: 0.6697 - val_accuracy: 0.5000 - val_loss: 4.3039
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7437 - loss: 0.7246 - val_accuracy: 0.5000 - val_loss: 4.3621
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9187 - loss: 0.4736 - val_accuracy: 0.5000 - val_loss: 4.4312
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9500 - loss: 0.4929 - val_accuracy: 0.5000 - val_loss: 4.4628
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8562 - loss: 0.5106 - val_accuracy: 0.5000 - val_loss: 4.4731
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.4164 - val_accuracy: 0.5000 - val_loss: 4.5278
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9750 - loss: 0.3869 - val_accuracy: 0.5000 - val_loss: 4.5622
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.3601 - val_accuracy: 0.5000 - val_loss: 4.5552
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.3341 - val_accuracy: 0.5000 - val_loss: 4.6850
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.3148 - val_accuracy: 0.5000 - val_loss: 4.7863
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9594 - loss: 0.3000 - val_accuracy: 0.5000 - val_loss: 4.7277
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.2551 - val_accuracy: 0.5000 - val_loss: 4.6741
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.2558 - val_accuracy: 0.5000 - val_loss: 4.7226
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.2177 - val_accuracy: 0.5000 - val_loss: 4.7793
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.1814 - val_accuracy: 0.5000 - val_loss: 4.7835
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.1900 - val_accuracy: 0.5000 - val_loss: 4.7882
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1638 - val_accuracy: 0.5000 - val_loss: 4.8427
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.1716 - val_accuracy: 0.5000 - val_loss: 4.8994
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1483 - val_accuracy: 0.5000 - val_loss: 4.9188
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1509 - val_accuracy: 0.5000 - val_loss: 4.9129
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.1360 - val_accuracy: 0.5000 - val_loss: 4.9296
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1144 - val_accuracy: 0.5000 - val_loss: 4.9629
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.1064 - val_accuracy: 0.5000 - val_loss: 4.9944
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1084 - val_accuracy: 0.5000 - val_loss: 5.0092
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1063 - val_accuracy: 0.5000 - val_loss: 5.0168
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0984 - val_accuracy: 0.5000 - val_loss: 5.0349
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0941 - val_accuracy: 0.5000 - val_loss: 5.0619
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0846 - val_accuracy: 0.5000 - val_loss: 5.0892
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0794 - val_accuracy: 0.5000 - val_loss: 5.1066
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0730 - val_accuracy: 0.5000 - val_loss: 5.1182
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0750 - val_accuracy: 0.5000 - val_loss: 5.1330
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0677 - val_accuracy: 0.5000 - val_loss: 5.1515
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0680 - val_accuracy: 0.5000 - val_loss: 5.1699
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0605 - val_accuracy: 0.5000 - val_loss: 5.1826
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0620 - val_accuracy: 0.5000 - val_loss: 5.1892
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0577 - val_accuracy: 0.5000 - val_loss: 5.2001
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0555 - val_accuracy: 0.5000 - val_loss: 5.2168
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0538 - val_accuracy: 0.5000 - val_loss: 5.2307
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0500 - val_accuracy: 0.5000 - val_loss: 5.2411
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0492 - val_accuracy: 0.5000 - val_loss: 5.2484
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0490 - val_accuracy: 0.5000 - val_loss: 5.2578
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0475 - val_accuracy: 0.5000 - val_loss: 5.2692
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0431 - val_accuracy: 0.5000 - val_loss: 5.2825
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0415 - val_accuracy: 0.5000 - val_loss: 5.2941
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0429 - val_accuracy: 0.5000 - val_loss: 5.3020
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0409 - val_accuracy: 0.5000 - val_loss: 5.3106
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0374 - val_accuracy: 0.5000 - val_loss: 5.3204
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0388 - val_accuracy: 0.5000 - val_loss: 5.3320
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0368 - val_accuracy: 0.5000 - val_loss: 5.3441
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0361 - val_accuracy: 0.5000 - val_loss: 5.3552
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0330 - val_accuracy: 0.5000 - val_loss: 5.3645
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0341 - val_accuracy: 0.5000 - val_loss: 5.3725
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0327 - val_accuracy: 0.5000 - val_loss: 5.3812
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0303 - val_accuracy: 0.5000 - val_loss: 5.3905
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0314 - val_accuracy: 0.5000 - val_loss: 5.3986
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0301 - val_accuracy: 0.5000 - val_loss: 5.4059
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0295 - val_accuracy: 0.5000 - val_loss: 5.4124
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 0.5000 - val_loss: 5.4195
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0280 - val_accuracy: 0.5000 - val_loss: 5.4280
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0273 - val_accuracy: 0.5000 - val_loss: 5.4366
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0266 - val_accuracy: 0.5000 - val_loss: 5.4463
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0254 - val_accuracy: 0.5000 - val_loss: 5.4558
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0240 - val_accuracy: 0.5000 - val_loss: 5.4648
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 0.5000 - val_loss: 5.4720
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0234 - val_accuracy: 0.5000 - val_loss: 5.4790
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 0.5000 - val_loss: 5.4855
#
# Translations:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# English: hello
# French: bonjour end
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# English: thank you
# French: bonjour end
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# English: your name
# French: comment end end
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# English: how are you
# French: comment ça va end
